# %% [markdown]
# <!-- filepath: d:\LM\VSCode\LogicMojo-AI-ML-March26-SanthoshKumar\practice\dsa\cheatsheet\twopointers.ipynb -->
#
# # Two Pointers Cheatsheet
#
# ## 🟢 1️⃣ OPPOSITE ENDS TWO POINTER
# ### ✅ EASY (Do ALL – in order)
# **From LeetCode:**
#
# - Two Sum II – Input Array Is Sorted
# - Valid Palindrome
# - Reverse String
# - Merge Sorted Array
# - Squares of a Sorted Array
# - Check If String Is a Palindrome (variation)
# - Remove Palindromic Subsequences
# - Reverse Vowels of a String
# - Intersection of Two Arrays (sorted approach)
# - Two Sum Less Than K
#
# ### 🔥 MEDIUM
# - Container With Most Water
# - 3Sum
# - 3Sum Closest
# - 4Sum
# - Sort Colors (also partition)
# - Boats to Save People
# - Partition Array According to Given Pivot
# - Find Pair With Given Difference
# - Trapping Rain Water
# - Valid Triangle Number
#
# ## 🟡 2️⃣ SLOW & FAST POINTER
# ### ✅ EASY
# **From LeetCode:**
#
# - Remove Duplicates from Sorted Array
# - Remove Element
# - Move Zeroes
# - Merge Sorted Array
# - Squares of Sorted Array (variation)
# - Remove Duplicates from Sorted Array II (basic try)
# - Keep Multiplying Found Values by Two
# - Duplicate Zeros
# - Replace Elements with Greatest on Right
# - Remove One Element to Make Array Strictly Increasing
#
# ### 🔥 MEDIUM
# - Sort Colors
# - Remove Duplicates II
# - Partition Labels
# - Wiggle Sort
# - Push Dominoes
# - Find All Duplicates in Array
# - Set Mismatch
# - Find Duplicate Number (cycle idea)
# - Rearrange Array by Sign
# - Apply Operations to an Array
#
# ## 🔵 3️⃣ SLIDING WINDOW (MOST IMPORTANT)
# ### ✅ EASY
# **From LeetCode:**
#
# - Maximum Average Subarray I
# - Contains Duplicate II
# - Find All Anagrams in a String (basic try)
# - Permutation in String (basic try)
# - Max Consecutive Ones
# - Max Consecutive Ones II
# - Minimum Recolors to Get K Consecutive Black Blocks
# - Defuse the Bomb
# - Number of Substrings with Only 1s
# - Longest Continuous Increasing Subsequence
#
# ### 🔥 MEDIUM
# - Longest Substring Without Repeating Characters
# - Minimum Size Subarray Sum
# - Subarray Product Less Than K
# - Longest Repeating Character Replacement
# - Max Consecutive Ones III
# - Fruit Into Baskets
# - Longest Substring with At Most K Distinct Characters
# - Find All Anagrams in a String
# - Permutation in String
# - Sliding Window Maximum
