# %% [markdown]
# ## 1. Data Loading + Initial Exploration
# ### Load All Datasets

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
customers = pd.read_csv(r"C:\Users\heman\Downloads\Santhu\VSCode\LogicMojo-AI-ML-March26-SanthoshKumar\projects\ecommerce_project\files\python_project_aiml_logicmojo_dataset\customers.csv")

print(customers.head())
customers.info()
customers.describe()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
# ...

# %%
orders = pd.read_csv(r"C:\Users\heman\Downloads\Santhu\VSCode\LogicMojo-AI-ML-March26-SanthoshKumar\projects\ecommerce_project\files\python_project_aiml_logicmojo_dataset\orders.csv")
orders.head()
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
order_items = pd.read_csv(r"C:\Users\heman\Downloads\Santhu\VSCode\LogicMojo-AI-ML-March26-SanthoshKumar\projects\ecommerce_project\files\python_project_aiml_logicmojo_dataset\order_item.csv")
order_items.head()
order_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
payments = pd.read_csv(r"C:\Users\heman\Downloads\Santhu\VSCode\LogicMojo-AI-ML-March26-SanthoshKumar\projects\ecommerce_project\files\python_project_aiml_logicmojo_dataset\payments.csv")
payments.head()
payments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
reviews = pd.read_csv(r"C:\Users\heman\Downloads\Santhu\VSCode\LogicMojo-AI-ML-March26-SanthoshKumar\projects\ecommerce_project\files\python_project_aiml_logicmojo_dataset\reviews.csv")
reviews.head()
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %%
products = pd.read_csv(r"C:\Users\heman\Downloads\Santhu\VSCode\LogicMojo-AI-ML-March26-SanthoshKumar\projects\ecommerce_project\files\python_project_aiml_logicmojo_dataset\products.csv")
products.head()
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
sellers = pd.read_csv(r"C:\Users\heman\Downloads\Santhu\VSCode\LogicMojo-AI-ML-March26-SanthoshKumar\projects\ecommerce_project\files\python_project_aiml_logicmojo_dataset\sellers.csv")
sellers.head()
sellers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %%
category_translation = pd.read_csv(r"C:\Users\heman\Downloads\Santhu\VSCode\LogicMojo-AI-ML-March26-SanthoshKumar\projects\ecommerce_project\files\python_project_aiml_logicmojo_dataset\category_translation.csv" )
category_translation.head()
category_translation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB

# %%
location = pd.read_csv(r"C:\Users\heman\Downloads\Santhu\VSCode\LogicMojo-AI-ML-March26-SanthoshKumar\projects\ecommerce_project\files\python_project_aiml_logicmojo_dataset\location.csv")
location.head()
# location.info()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %% [markdown]
# ## 2. Data Cleaning and Preprocessing
#
# ### 2.1 - Handling Mssing Values

# %%
# ============================================================
# Handling Missing Values
# ============================================================
# Missing value analysis was performed on all datasets.
# Missing values were handled based on business context,
# data importance, and analytical relevance.
# Business-state null values were retained where appropriate,
# while metadata and numerical fields were imputed using
# suitable strategies.
# ============================================================



# ============================================================
# Customers Dataset
# ============================================================

customers.isna().sum()

# This dataset does not contain missing values.
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
# ============================================================
# Orders Dataset
# ============================================================

orders.isna().sum()

# The orders dataset contains null values in the following columns:
# - order_approved_at
# - order_delivered_carrier_date
# - order_delivered_customer_date

# These null values were analyzed using order_status to understand
# whether they represent actual data quality issues or valid
# business scenarios.

# ============================================================
# Orders_approved_at Analysis
# ============================================================

# Check order status for missing approval dates
orders[orders['order_approved_at'].isnull()]['order_status'].value_counts()

# Replacing order_approved_at null values with order_purchase_timestamp for delivered orders
mask = (
    (orders['order_approved_at'].isna()) &
    (orders['order_status'] == 'delivered')
)

orders.loc[mask, 'order_approved_at'] = orders.loc[
    mask,
    'order_purchase_timestamp'
]

# print(orders[(orders['order_approved_at'].isna()) & (orders['order_status'] == 'delivered')].sum())


# ============================================================
# order_delivered_carrier_date Analysis
# ============================================================

# Check order statuses where carrier delivery date is missing
print(
    orders[
        orders['order_delivered_carrier_date'].isna()
    ]['order_status'].value_counts()
)

# -------------------------------------------------------------
# Observation:
#
# - For statuses like:
#     unavailable, canceled, processing, created, approved
#   missing carrier date is logically acceptable because
#   the order may not have reached shipping stage.
#
# - But for 'delivered' orders:
#   carrier delivery date SHOULD exist because an order
#   cannot be delivered to customer without first being
#   handed over to the carrier.
#
# - Therefore, delivered orders with missing
#   order_delivered_carrier_date are inconsistent records.
# -------------------------------------------------------------


# Display those inconsistent delivered rows
orders[
    (orders['order_delivered_carrier_date'].isna()) &
    (orders['order_status'] == 'delivered')
].head(50)


# -------------------------------------------------------------
# Create a mask for inconsistent rows:
#
# Condition:
#   1. carrier delivery date is missing
#   2. order status is delivered
#
# These rows violate normal business workflow.
# -------------------------------------------------------------
mask = (
    (orders['order_delivered_carrier_date'].isna()) &
    (orders['order_status'] == 'delivered')
)


# -------------------------------------------------------------
# Remove inconsistent rows from dataset
#
# '~mask' means:
#   keep all rows EXCEPT rows where mask=True
#
# Since only 2 rows are affected,
# dropping them is safer than imputing artificial values.
# -------------------------------------------------------------
orders = orders[~mask]




# ============================================================
# order_delivered_customer_date Analysis
# ============================================================

# Check order statuses where customer delivery date is missing
print(
    orders[
        orders['order_delivered_customer_date'].isna()
    ]['order_status'].value_counts()
)

# Display inconsistent delivered rows
orders[
    (orders['order_delivered_customer_date'].isna()) &
    (orders['order_status'] == 'delivered')
]

# Create mask for inconsistent rows
mask = (
    (orders['order_delivered_customer_date'].isna()) &
    (orders['order_status'] == 'delivered')
)

# Remove inconsistent rows
orders = orders[~mask]
# Out:
# order_status
# unavailable    609
# canceled       550
# invoiced       314
# processing     301
# created          5
# approved         2
# delivered        2
# Name: count, dtype: int64
# order_status
# shipped        1107
# canceled        619
# unavailable     609
# invoiced        314
# processing      301
# delivered         7
# created           5
# approved          2
# Name: count, dtype: int64

# %%
# ============================================================
# Order Items Dataset
# ============================================================

order_items.isna().sum()

# This dataset does not contain missing values.
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %%
# ============================================================
# Payments Dataset
# ============================================================

payments.isna().sum()

# This dataset does not contain missing values.
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %%
# Check missing values in reviews dataset
# print(reviews.isna().sum())

# Fill missing review titles with placeholder text
reviews['review_comment_title'] = reviews[
    'review_comment_title'
].fillna('No Title')

# Fill missing review messages with placeholder text
reviews['review_comment_message'] = reviews[
    'review_comment_message'
].fillna('No Comment')

# Verify missing values after handling
print(reviews.isna().sum())
# Out:
# review_id                  0
# order_id                   0
# review_score               0
# review_comment_title       0
# review_comment_message     0
# review_creation_date       0
# review_answer_timestamp    0
# dtype: int64

# %%
# Check missing values in products dataset
print(products.isna().sum())

# ---------------------------------------------------------
# Product Dataset Missing Value Analysis
#
# Group 1:
# The following columns contain 610 missing values
# for the same rows:
#
# - product_category_name
# - product_name_lenght
# - product_description_lenght
# - product_photos_qty
#
# These columns represent important product metadata.
# Since major product information is missing,
# removing these rows is a better approach.
# ---------------------------------------------------------

# Display rows with missing product metadata
# print(products[products['product_category_name'].isna()].head(50))


# Remove rows with missing core product information
products = products.dropna(
    subset=[
        'product_category_name',
        'product_name_lenght',
        'product_description_lenght',
        'product_photos_qty'
    ]
)


# ---------------------------------------------------------
# Group 2:
# The following columns contain only 2 missing values:
#
# - product_weight_g
# - product_length_cm
# - product_height_cm
# - product_width_cm
#
# These columns represent physical product dimensions.
# Instead of removing rows, we fill missing values
# using median values.
# ---------------------------------------------------------

# Display rows with missing product dimensions
# print(products[products['product_weight_g'].isnull()].head(50))


# List of dimension columns
dimension_cols = [
    'product_weight_g',
    'product_length_cm',
    'product_height_cm',
    'product_width_cm'
]


# Fill missing dimension values using median
for col in dimension_cols:
    products[col] = products[col].fillna(
        products[col].median()
    )


# Verify missing values after handling
print(products.isna().sum())
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              0
# product_length_cm             0
# product_height_cm             0
# product_width_cm              0
# dtype: int64

# %% [markdown]
# ### 2.2 - Handling duplicate values

# %%
# ============================================================
# No Duplicate Values
# ============================================================


# customers.duplicated().sum()

# orders.duplicated().sum()

# print(order_items.duplicated().sum())

# payments.duplicated().sum()

# reviews.duplicated().sum()

# products.duplicated().sum()

# sellers.duplicated().sum()

# category_translation.duplicated().sum()

# location[location.duplicated()].tail(50)


# ============================================================
# Contains Duplicate Values
# ============================================================

# Check duplicate rows in location dataset
print(location.duplicated().sum())


# ---------------------------------------------------------
# Duplicate Analysis:
#
# - Some rows in the location dataset are exact duplicates
# - Same zip code can appear multiple times with
#   different latitude and longitude values
# - Only exact duplicate rows should be removed
# ---------------------------------------------------------


# Display duplicate rows
# print(location[location.duplicated()].head(50))


# Remove exact duplicate rows
# Keeps first occurrence and removes remaining duplicates
location = location.drop_duplicates()


# Verify duplicates after removal
print(location.duplicated().sum())
# Out:
# 261831
# 0

# %% [markdown]
# ### 2.3 - Convert date columns to datetime format

# %%
# ---------------------------------------------------------
# Convert date columns in orders dataset to datetime format
# ---------------------------------------------------------



orders['order_approved_at'] = pd.to_datetime(orders['order_approved_at'])
orders['order_delivered_carrier_date'] = pd.to_datetime(orders['order_delivered_carrier_date'])
orders['order_delivered_customer_date'] = pd.to_datetime(orders['order_delivered_customer_date'])
orders['order_purchase_timestamp'] = pd.to_datetime(orders['order_purchase_timestamp'])
orders['order_estimated_delivery_date'] = pd.to_datetime(orders['order_estimated_delivery_date'])
print(orders.dtypes)


# ---------------------------------------------------------
# Convert date columns in reviews dataset to datetime format
# ---------------------------------------------------------

reviews['review_creation_date'] = pd.to_datetime(reviews['review_creation_date'])

reviews['review_answer_timestamp'] = pd.to_datetime(reviews['review_answer_timestamp'])

print(reviews.dtypes)
# Out:
# order_id                                 object
# customer_id                              object
# order_status                             object
# order_purchase_timestamp         datetime64[ns]
# order_approved_at                datetime64[ns]
# order_delivered_carrier_date     datetime64[ns]
# order_delivered_customer_date    datetime64[ns]
# order_estimated_delivery_date    datetime64[ns]
# dtype: object
# review_id                          object
# order_id                           object
# review_score                        int64
# review_comment_title               object
# review_comment_message             object
# review_creation_date       datetime64[ns]
# review_answer_timestamp    datetime64[ns]
# dtype: object

# %%
# =========================================================
# Validate Data Types and Ranges
# =========================================================

# Check datatypes of all datasets
print(customers.dtypes)
print(orders.dtypes)
print(products.dtypes)
print(reviews.dtypes)
print(payments.dtypes)
print(order_items.dtypes)
print(sellers.dtypes)
print(location.dtypes)
print(category_translation.dtypes)


# ---------------------------------------------------------
# Validate review score range
# Review scores should be between 1 and 5
# ---------------------------------------------------------

print("Minimum Review Score :", reviews['review_score'].min())
print("Maximum Review Score :", reviews['review_score'].max())


# ---------------------------------------------------------
# Validate payment values
# Payment values should not be negative
# ---------------------------------------------------------

print(payments[payments['payment_value'] < 0])


# ---------------------------------------------------------
# Validate product dimensions
# Product dimensions and weight should not be negative
# ---------------------------------------------------------

print(products[products['product_weight_g'] < 0])

print(products[products['product_length_cm'] < 0])

print(products[products['product_height_cm'] < 0])

print(products[products['product_width_cm'] < 0])


# ---------------------------------------------------------
# Validate order item price and freight values
# Price and freight value should not be negative
# ---------------------------------------------------------

print(order_items[order_items['price'] < 0])

print(order_items[order_items['freight_value'] < 0])


# ---------------------------------------------------------
# Validate delivery dates
# Delivery date should be after purchase date
# ---------------------------------------------------------

print(
    orders[
        orders['order_delivered_customer_date']
        < orders['order_purchase_timestamp']
    ]
)



# =========================================================
# Standardize Column Names
# =========================================================

# ---------------------------------------------------------
# Some columns contain spelling inconsistencies
# Rename them to more readable and standardized names
# ---------------------------------------------------------

products.rename(columns={

    'product_name_lenght': 'product_name_length',

    'product_description_lenght': 'product_description_length'

}, inplace=True)


# ---------------------------------------------------------
# Verify updated column names
# ---------------------------------------------------------

print(products.columns)
# Out:
# customer_id                 object
# customer_unique_id          object
# customer_zip_code_prefix     int64
# customer_city               object
# customer_state              object
# dtype: object
# order_id                                 object
# customer_id                              object
# order_status                             object
# order_purchase_timestamp         datetime64[ns]
# order_approved_at                datetime64[ns]
# order_delivered_carrier_date     datetime64[ns]
# order_delivered_customer_date    datetime64[ns]
# order_estimated_delivery_date    datetime64[ns]
# dtype: object
# product_id                     object
# product_category_name          object
# product_name_lenght           float64
# product_description_lenght    float64
# product_photos_qty            float64
# product_weight_g              float64
# product_length_cm             float64
# product_height_cm             float64
# product_width_cm              float64
# dtype: object
# ...

# %% [markdown]
# ### 3: Data Integration (Critical Component)

# %%
# Step 1 — Orders + Customers

# Merge orders with customers dataset

master_df = pd.merge(
    orders,
    customers,
    on='customer_id',
    how='left'
)
# print(orders.shape)
# print(customers.shape)
# Check shape after merge
print(master_df.shape)
# print(master_df.head())



#Step 2 — Merge Order Items

# Merge order items into master dataset

master_df = pd.merge(
    master_df,
    order_items,
    on='order_id',
    how='left'
)

# Check shape after merge
# print(order_items.shape)
print(master_df.shape)


# Step 3 — Merge Products

# Merge products dataset

master_df = pd.merge(
    master_df,
    products,
    on='product_id',
    how='left'
)

# print(products.shape)
# Check shape after merge
print(master_df.shape)

# Step 4 — Merge Payments

# Merge payments dataset

master_df = pd.merge(
    master_df,
    payments,
    on='order_id',
    how='left'
)

# print(payments.shape)
# Check shape after merge
print(master_df.shape)


#Step 5 — Merge Reviews

# Merge reviews dataset

master_df = pd.merge(
    master_df,
    reviews,
    on='order_id',
    how='left'
)

# print(reviews.shape)
# Check shape after merge
print(master_df.shape)


# Step 6 — Merge Sellers

# Merge sellers dataset

master_df = pd.merge(
    master_df,
    sellers,
    on='seller_id',
    how='left'
)

# print(sellers.shape)
# Check shape after merge
print(master_df.shape)


# Step 7 — Merge Category Translation

# Merge category translation dataset

master_df = pd.merge(
    master_df,
    category_translation,
    on='product_category_name',
    how='left'
)

# print(category_translation.shape)


# Display final master dataset

print(master_df.head())

print(master_df.info())

print(master_df.shape)
# Out:
# (99432, 12)
# (113416, 18)
# (113416, 26)
# (118425, 30)
# (119134, 36)
# (119134, 39)
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 3    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 4    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# ...

# %%
print(master_df.head())
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 3    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 4    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %% [markdown]
# ### 4. Feature Engineering

# %%
# ---------------------------------------------------------
# 1. Total Order Value
#
# Calculate total amount spent per order
# using price + freight value
# ---------------------------------------------------------

master_df['total_order_value'] = (
    master_df['price'] + master_df['freight_value']
)

print(master_df[['total_order_value']].head())


# ---------------------------------------------------------
# 2. Delivery Time
#
# Calculate total delivery time in days
# from purchase date to customer delivery date
# ---------------------------------------------------------

master_df['delivery_time_days'] = (
    master_df['order_delivered_customer_date']
    - master_df['order_purchase_timestamp']
).dt.days

print(master_df[['delivery_time_days']].head())


# ---------------------------------------------------------
# 3. Number of Items Per Order
#
# Count total products present in each order
# ---------------------------------------------------------

master_df['items_per_order'] = master_df.groupby(
    'order_id'
)['product_id'].transform('count')

print(master_df[['items_per_order']].head())


# ---------------------------------------------------------
# 4. Customer Purchase Frequency
#
# Count total orders placed by each customer
# ---------------------------------------------------------

master_df['customer_purchase_frequency'] = master_df.groupby(
    'customer_id'
)['order_id'].transform('nunique')

print(master_df[['customer_purchase_frequency']].head())


# ---------------------------------------------------------
# 5. Customer Lifetime Value (CLV)
#
# Calculate total spending by each customer
# ---------------------------------------------------------

master_df['customer_lifetime_value'] = master_df.groupby(
    'customer_id'
)['total_order_value'].transform('sum')

print(master_df[['customer_lifetime_value']].head())


# ---------------------------------------------------------
# 6. Average Order Value (AOV)
#
# Calculate average spending per customer order
# ---------------------------------------------------------

master_df['average_order_value'] = (
    master_df['customer_lifetime_value']
    / master_df['customer_purchase_frequency']
)

print(master_df[['average_order_value']].head())


# ---------------------------------------------------------
# Display newly created features
# ---------------------------------------------------------

print(master_df[[
    'total_order_value',
    'delivery_time_days',
    'items_per_order',
    'customer_purchase_frequency',
    'customer_lifetime_value',
    'average_order_value'
]].head())
# Out:
#    total_order_value
# 0              38.71
# 1              38.71
# 2              38.71
# 3             141.46
# 4             179.12
#    delivery_time_days
# 0                 8.0
# 1                 8.0
# 2                 8.0
# 3                13.0
# 4                 9.0
#    items_per_order
# 0                3
# 1                3
# 2                3
# 3                1
# 4                1
#    customer_purchase_frequency
# 0                            1
# 1                            1
# 2                            1
# 3                            1
# 4                            1
#    customer_lifetime_value
# 0                   116.13
# 1                   116.13
# 2                   116.13
# 3                   141.46
# 4                   179.12
#    average_order_value
# 0               116.13
# 1               116.13
# 2               116.13
# 3               141.46
# 4               179.12
#    total_order_value  delivery_time_days  items_per_order  \
# ...

# %% [markdown]
# ### 5. Exploratory Data Analysis (EDA)

# %%
# =========================================================
# Exploratory Data Analysis (EDA)
# =========================================================



# =========================================================
# 1. Customer Analysis
# =========================================================

# ---------------------------------------------------------
# New vs Repeat Customers
# ---------------------------------------------------------

new_customers = master_df[
    master_df['customer_purchase_frequency'] == 1
]['customer_id'].nunique()

repeat_customers = master_df[
    master_df['customer_purchase_frequency'] > 1
]['customer_id'].nunique()

print("New Customers :", new_customers)
print("Repeat Customers :", repeat_customers)



# ---------------------------------------------------------
# High-value vs Low-value Customers
# ---------------------------------------------------------

median_clv = master_df[
    'customer_lifetime_value'
].median()

high_value_customers = master_df[
    master_df['customer_lifetime_value'] >= median_clv
]['customer_id'].nunique()

low_value_customers = master_df[
    master_df['customer_lifetime_value'] < median_clv
]['customer_id'].nunique()

print("High-value Customers :", high_value_customers)
print("Low-value Customers :", low_value_customers)



# ---------------------------------------------------------
# Geographic Distribution of Customers
# ---------------------------------------------------------

customer_geo = master_df.groupby(
    'customer_state'
)['customer_id'].nunique().sort_values(ascending=False)

print(customer_geo.head(10))



# =========================================================
# 2. Revenue and Order Analysis
# =========================================================

# ---------------------------------------------------------
# Monthly Revenue Trends
# ---------------------------------------------------------

master_df['order_month'] = master_df[
    'order_purchase_timestamp'
].dt.to_period('M')

monthly_revenue = master_df.groupby(
    'order_month'
)['total_order_value'].sum()

print(monthly_revenue)



# ---------------------------------------------------------
# Order Volume Trends
# ---------------------------------------------------------

order_volume = master_df.groupby(
    'order_month'
)['order_id'].nunique()

print(order_volume)



# ---------------------------------------------------------
# Peak Sales Periods
# ---------------------------------------------------------

peak_sales = monthly_revenue.sort_values(
    ascending=False
)

print(peak_sales.head(10))



# =========================================================
# 3. Product Analysis
# =========================================================

# ---------------------------------------------------------
# Top-selling Product Categories
# ---------------------------------------------------------

top_categories = master_df[
    'product_category_name_english'
].value_counts()

print(top_categories.head(10))



# ---------------------------------------------------------
# Revenue Contribution by Category
# ---------------------------------------------------------

category_revenue = master_df.groupby(
    'product_category_name_english'
)['total_order_value'].sum().sort_values(
    ascending=False
)

print(category_revenue.head(10))



# ---------------------------------------------------------
# Product Demand Distribution
# ---------------------------------------------------------

product_demand = master_df.groupby(
    'product_id'
)['order_id'].count().sort_values(
    ascending=False
)

print(product_demand.head(10))



# =========================================================
# 4. Seller Analysis
# =========================================================

# ---------------------------------------------------------
# Top-performing Sellers
# ---------------------------------------------------------

top_sellers = master_df.groupby(
    'seller_id'
)['total_order_value'].sum().sort_values(
    ascending=False
)

print(top_sellers.head(10))



# ---------------------------------------------------------
# Seller Contribution to Revenue
# ---------------------------------------------------------

seller_revenue = master_df.groupby(
    'seller_id'
)['total_order_value'].sum()

print(seller_revenue.head(10))



# ---------------------------------------------------------
# Seller Distribution
# ---------------------------------------------------------

seller_distribution = master_df[
    'seller_state'
].value_counts()

print(seller_distribution)



# =========================================================
# 5. Review and Satisfaction Analysis
# =========================================================

# ---------------------------------------------------------
# Distribution of Review Scores
# ---------------------------------------------------------

review_distribution = master_df[
    'review_score'
].value_counts().sort_index()

print(review_distribution)



# ---------------------------------------------------------
# Relationship Between Delivery Time and Ratings
# ---------------------------------------------------------

delivery_rating = master_df.groupby(
    'review_score'
)['delivery_time_days'].mean()

print(delivery_rating)



# ---------------------------------------------------------
# Dissatisfaction Patterns
# Low review scores = 1 or 2
# ---------------------------------------------------------

dissatisfied_customers = master_df[
    master_df['review_score'] <= 2
]

print(
    dissatisfied_customers[[
        'review_score',
        'delivery_time_days',
        'order_status'
    ]].head(10)
)
# Out:
# New Customers : 99432
# Repeat Customers : 0
# High-value Customers : 43885
# Low-value Customers : 55547
# customer_state
# SP    41738
# RJ    12852
# MG    11635
# RS     5465
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# Name: customer_id, dtype: int64
# order_month
# 2016-09        354.75
# 2016-10      58730.85
# 2016-12         19.62
# 2017-01     148030.11
# 2017-02     303648.31
# 2017-03     459778.64
# 2017-04     449707.81
# 2017-05     634568.22
# 2017-06     531052.06
# 2017-07     631341.57
# 2017-08     706168.95
# 2017-09     767131.72
# 2017-10     808911.33
# 2017-11    1231939.47
# 2017-12     898427.92
# 2018-01    1158742.84
# 2018-02    1039011.65
# 2018-03    1209080.30
# 2018-04    1201102.21
# 2018-05    1193204.98
# 2018-06    1075224.11
# 2018-07    1097418.78
# 2018-08    1038395.74
# 2018-09        166.46
# 2018-10          0.00
# Freq: M, Name: total_order_value, dtype: float64
# order_month
# 2016-09       4
# ...

# %% [markdown]
# ### 6. Data Visualization

# %%
# =========================================================
# Data Visualization
# =========================================================

import matplotlib.pyplot as plt
import seaborn as sns



# =========================================================
# 1. Time Series Plot - Monthly Sales Trend
# =========================================================

monthly_sales = master_df.groupby(
    'order_month'
)['total_order_value'].sum()

plt.figure(figsize=(12, 5))

monthly_sales.plot()

plt.title('Monthly Sales Trend')

plt.xlabel('Month')

plt.ylabel('Revenue')

plt.show()



# =========================================================
# 2. Bar Chart - Top Product Categories
# =========================================================

top_categories = master_df[
    'product_category_name_english'
].value_counts().head(10)

plt.figure(figsize=(12, 5))

top_categories.plot(kind='bar')

plt.title('Top 10 Product Categories')

plt.xlabel('Category')

plt.ylabel('Count')

plt.show()



# =========================================================
# 3. Histogram - Delivery Time Distribution
# =========================================================

plt.figure(figsize=(10, 5))

plt.hist(
    master_df['delivery_time_days'].dropna(),
    bins=30
)

plt.title('Delivery Time Distribution')

plt.xlabel('Delivery Time (Days)')

plt.ylabel('Frequency')

plt.show()



# =========================================================
# 4. Box Plot - Outlier Detection
# =========================================================

plt.figure(figsize=(10, 5))

sns.boxplot(
    x=master_df['total_order_value']
)

plt.title('Total Order Value Outliers')

plt.show()



# =========================================================
# 5. Heatmap - Correlation Analysis
# =========================================================

correlation_data = master_df[[
    'price',
    'freight_value',
    'total_order_value',
    'delivery_time_days',
    'review_score'
]]

correlation_matrix = correlation_data.corr()

plt.figure(figsize=(8, 6))

sns.heatmap(
    correlation_matrix,
    annot=True,
    cmap='coolwarm'
)

plt.title('Correlation Heatmap')

plt.show()

# %% [markdown]
# ### 7. Business Insights and Recommendations

# %%
# =========================================================
# 1. Top Revenue-driving Factors
# =========================================================

# Top product categories by revenue
top_category_revenue = master_df.groupby(
    'product_category_name_english'
)['total_order_value'].sum().sort_values(
    ascending=False
)

print("Top Revenue-driving Categories")
print(top_category_revenue.head(10))


# Top sellers by revenue
top_sellers = master_df.groupby(
    'seller_id'
)['total_order_value'].sum().sort_values(
    ascending=False
)

print("\nTop Revenue-driving Sellers")
print(top_sellers.head(10))



# =========================================================
# 2. Customer Behavior Patterns
# =========================================================

# New vs Repeat Customers
new_customers = master_df[
    master_df['customer_purchase_frequency'] == 1
]['customer_id'].nunique()

repeat_customers = master_df[
    master_df['customer_purchase_frequency'] > 1
]['customer_id'].nunique()

print("\nNew Customers :", new_customers)
print("Repeat Customers :", repeat_customers)


# Average Order Value
average_order_value = master_df[
    'average_order_value'
].mean()

print("\nAverage Order Value :", average_order_value)


# High-value Customers
high_value_customers = master_df[
    master_df['customer_lifetime_value']
    >= master_df['customer_lifetime_value'].median()
]['customer_id'].nunique()

print("High-value Customers :", high_value_customers)



# =========================================================
# 3. Operational Inefficiencies
# =========================================================

# Average delivery time
average_delivery_time = master_df[
    'delivery_time_days'
].mean()

print("\nAverage Delivery Time :", average_delivery_time)


# Delayed deliveries
delayed_orders = master_df[
    master_df['delivery_time_days'] > 10
]['order_id'].nunique()

print("Delayed Orders :", delayed_orders)


# Low review scores
low_reviews = master_df[
    master_df['review_score'] <= 2
]['order_id'].nunique()

print("Low Review Orders :", low_reviews)



# =========================================================
# 4. Strategic Recommendations
# =========================================================

print("\nStrategic Recommendations")

print("""
1. Focus on top-performing product categories
   to maximize revenue growth.

2. Improve customer retention strategies
   to increase repeat purchases.

3. Reduce delivery delays to improve
   customer satisfaction and review scores.

4. Support high-performing sellers and
   optimize underperforming seller operations.

5. Monitor low-rated orders to identify
   operational and service issues.

6. Use customer purchase behavior for
   personalized marketing and recommendations.
""")
# Out:
# Top Revenue-driving Categories
# product_category_name_english
# health_beauty            1491397.76
# watches_gifts            1358529.45
# bed_bath_table           1327662.02
# sports_leisure           1205003.85
# computers_accessories    1104241.91
# furniture_decor           955173.24
# housewares                823623.50
# cool_stuff                752702.21
# auto                      714297.12
# garden_tools              625387.31
# Name: total_order_value, dtype: float64
#
# Top Revenue-driving Sellers
# seller_id
# 53243585a1d6dc2643021fd1853d8905    258882.28
# 4869f7a5dfa277a7dca6462dcf3b52b2    258625.52
# 7c67e1448b00f6e969d365cea6b010ab    254387.70
# 4a3ca9315b744ce9f8e9374361493884    253535.64
# fa1c13f2614d7b5c4749cbc52fecda94    214454.82
# da8622b14eb17ae2831f4ac5b9dab84a    198621.24
# 7e93a43ef30c4f03f38b393420bc753a    189475.90
# 1025f0e2d44d7041d6cf58b6550e0bfa    178696.05
# 7a67c85e85bb2ce8582c35f2203ad736    172887.23
# ...
