# %% [markdown]
# REGEX
# Q1. Division with Exception Handling
#
# Write a program that takes two numbers and safely performs division. Handle division by zero using try-except.

# %%
def safe_devision(num1, num2):
    try:
        # Try dividing 10 with 0
        res = num1 / num2
        return res
    except ZeroDivisionError:
        return "Error : Cannot divide by zero!"
print(safe_devision(10,0))
# Out:
# Error : Cannot divide by zero!

# %% [markdown]
# Q2. String to Integer Conversion
#
# Given a list:
#
# data = ["10", "20", "abc", "30"]
#
# Convert all values to integers. Skip invalid values using exception handling.

# %%
data = ["10", "20", "abc", "30"]

converted_numbers = []

for item in data:
    try:
        # Try converting the string to an integer
        number = int(item)
        converted_numbers.append(number)
    except ValueError:
        # Skip invalid values and print a warning
        print(f"Skipping invalid value: '{item}'")

print("Converted integers:", converted_numbers)
# Out:
# Skipping invalid value: 'abc'
# Converted integers: [10, 20, 30]

# %% [markdown]
# Q3. Multiple Exception Handling
#
# Write a program that:
#
# Takes user input Converts it to integer Divides 100 by that number
#
# Handle:
#
# ValueError ZeroDivisionError

# %%
def divide_100():
    try:
        #take user input and convert it to an integer
        num = int(input("Enter a number :: "))

        #Divide 100 by the user input
        result = 100 / num

        #Display the result
        print(f"Result of 100 divide by {num} is {result}")

    except ValueError:
        print("Error: Please enter a valid number")
    except ZeroDivisionError:
        print("Error: Cannot divide by zero!")

divide_100()
# Out:
# Error: Please enter a valid number

# %% [markdown]
# Q4. Using finally
#
# Write a program that:
#
# Opens a file (dummy) Prints a message Ensures a “Closing file” message always runs using finally

# %%
try:
    open("dummy.txt", "r")
    print("File opened")
except:
    print("Error occurred")
finally:
    print("Closing file")  # This message always runs
# Out:
# Error occurred
# Closing file

# %% [markdown]
# Q5. Using assert
#
# Write a program that checks if a number is positive using assert.

# %%
try:
    num = int(input("Enter a number :: "))

    assert num > 0, "Number must be positive"

    print(f"{num} is a positive number")
except AssertionError as e:
    print(f"Assertion error : {e}")
except ValueError:
    print("Invalid input! Please enter a valid number.")
# Out:
# Assertion error : Number must be positive

# %% [markdown]
# Q6. Clean Text
#
# Given:
#
# text = " Hello Python "
#
# Remove spaces and convert to lowercase.

# %%
text = " Hello Python "

#strip() + replace() + lower() - Remove surrounding + between
text = text.strip().replace(" ", "").lower()

print(f"text: '{text}'")  # 'hellopython' (no spaces)
# Out:
# text: 'hellopython'

# %% [markdown]
# Q7. Replace Words
#
# Replace all occurrences of "Python" with "AI" in:
#
# text = "Python is great. Python is easy."

# %%
text = "Python is great. Python is easy."

# using replace
text = text.replace("Python", "AI" )

text
# Out:
# 'AI is great. AI is easy.'

# %% [markdown]
# Q8. Split and Join
#
# Convert:
#
# text = "apple,banana,orange"
#
# Into:
#
# "apple banana orange"

# %%
text = "apple,banana,orange"

# using split and join
text = " ".join(text.split(","))

text
# Out:
# 'apple banana orange'

# %% [markdown]
# Q9. Count Words
#
# Count number of words in a sentence using split.

# %%
text = "my name is santhosh kumar, and I am learning python programming"

# splitting char first and finding the len of it
len(text.split(" "))
# Out:
# 11

# %% [markdown]
# Q10. Reverse Words
#
# Reverse words in a string:
#
# "I love AI"

# %%
text = "I love AI"

# using slicing to reverse the string
text[::-1]
# Out:
# 'IA evol I'

# %% [markdown]
# Q11. Find Digits
#
# Extract all digits from:
#
# text = "My number is 98765"

# %%
text = "My number is 98765"

digitText = ""

# Iterate through each character in the string
for char in text:
    if char.isdigit():
        digitText += char

digitText
# Out:
# '98765'

# %% [markdown]
# Q12. Find Words Starting with 'a'
#
# From:
#
# text = "apple banana avocado berry"
#
# Extract words starting with 'a'.

# %%
text = "apple banana avocado berry"

# Normal for loop approach
result = []
for word in text.split():
    if word.startswith('a'):
        result.append(word)

result  # ['apple', 'avocado']
# Out:
# ['apple', 'avocado']

# %% [markdown]
# Q13. Extract Emails
#
# Extract emails from:
#
# text = "Contact: test@gmail.com, admin@yahoo.com"

# %%
text = "Contact: test@gmail.com, admin@yahoo.com"

print(" ".join(text.split(",")))
# Out:
# Contact: test@gmail.com  admin@yahoo.com

# %% [markdown]
# Q14. Validate Phone Numbers
#
# Extract valid 10-digit phone numbers from:
#
# text = "Call 9876543210 or 12345"

# %%
import re

text = "Call 9876543210 or 12345"

phones = re.findall(r'\b\d{10}\b', text)

print(phones)
# Out:
# ['9876543210']

# %% [markdown]
# Q15. Replace Digits
#
# Replace all digits with "X" in:
#
# text = "My number is 98765"

# %%
text = "My number is 98765"
result = ""

for i in range(len(text)):
    if text[i].isdigit():
        # If the character is a digit, replace it with 'X'
        result += "X"
    else:
        result += text[i]

result
# Out:
# 'My number is XXXXX'

# %% [markdown]
# Q16. Extract Dates
#
# Extract date from:
#
# text = "Today is 2026-03-28"
#
# Return:
#
# Year Month Day

# %%
text = "Today is 2026-03-28"

# Simple and readable
date_str = text.split()[-1]  # Get the date part
year, month, day = date_str.split('-')  # Split into components

print(f"Year: {year}")
print(f"Month: {month}")
print(f"Day: {day}")
# Out:
# Year: 2026
# Month: 03
# Day: 28

# %% [markdown]
# Q. 17 Extract numbers followed by "rs":
#
# text = "100rs 200usd 300rs"

# %%
text = "100rs 200usd 300rs"

# Simple loop approach
result = []
for word in text.split():
    if word.endswith('rs'):
        result.append(word[:-2])

print(result)  # ['100', '300']
# Out:
# ['100', '300']

# %% [markdown]
# Q. 18 Extract numbers that come after "rs":
#
# text = "rs100 rs200 usd300"

# %%
text = "rs100 rs200 usd300"

# Simple loop approach
result = []
for word in text.split():
    if word.startswith('rs'):
        result.append(word[2:])

print(result)  # ['100', '200']
# Out:
# ['100', '200']

# %% [markdown]
# Q. 19 Extract Valid Transaction Records Using a Single Regex Pattern
#
# You are given a messy log string:
#
# log = """ ID:TXN12345 | User: Mahipal_01 | Email: mahi123@gmail.com | Phone: +91-9876543210 | Amount: Rs.5000 ID:TXN12 | User: @InvalidUser | Email: wronggmail.com | Phone: 98765 | Amount: Rs.-200 ID:TXN99999 | User: Ravi_kumar | Email: ravi.kumar@yahoo.com | Phone: +91-9123456789 | Amount: USD300 ID:TXN54321 | User: Sita99 | Email: sita99@gmail | Phone: +91-9999999999 | Amount: Rs.7000
#
# Write a single REGEX pattern that extracts ONLY VALID records where: CONDITIONS (VERY IMPORTANT) Transaction ID Format: TXN followed by exactly 5 digits Example: TXN12345 Use: ^, {}, \d
#
# Username Only letters, numbers, underscore Must start with a letter Example: Mahipal_01 Use: [a-zA-Z], \w, +
#
# Email Valid format: word@word.domain Example: test123@gmail.com Use: \w, ., @, +, .
#
# Phone Number Format: +91-XXXXXXXXXX Exactly 10 digits Use: +, \d, {}
#
# Amount Currency: Rs or USD Amount must be positive Example: Rs.5000, USD300 Use: (rs|usd), \d+, ?
#
# EXPECTED OUTPUT
#
# Only valid records should match:
#
# [ "ID:TXN12345 | User: Mahipal_01 | Email: mahi123@gmail.com | Phone: +91-9876543210 | Amount: Rs.5000",
#
# "ID:TXN99999 | User: Ravi_kumar | Email: ravi.kumar@yahoo.com | Phone: +91-9123456789 | Amount: USD300" ]

# %%
import re

log = """
ID:TXN12345 | User: Mahipal_01 | Email: mahi123@gmail.com | Phone: +91-9876543210 | Amount: Rs.5000
ID:TXN12 | User: @InvalidUser | Email: wronggmail.com | Phone: 98765 | Amount: Rs.-200
ID:TXN99999 | User: Ravi_kumar | Email: ravi.kumar@yahoo.com | Phone: +91-9123456789 | Amount: USD300
ID:TXN54321 | User: Sita99 | Email: sita99@gmail | Phone: +91-9999999999 | Amount: Rs.7000
"""

pattern = r'ID:TXN\d{5} \| User: [A-Za-z]\w* \| Email: [\w.]+@\w+\.\w+ \| Phone: \+91-\d{10} \| Amount: (?:Rs\.\d+|USD\d+)'

result = re.findall(pattern, log)

print(result)
# Out:
# ['ID:TXN12345 | User: Mahipal_01 | Email: mahi123@gmail.com | Phone: +91-9876543210 | Amount: Rs.5000', 'ID:TXN99999 | User: Ravi_kumar | Email: ravi.kumar@yahoo.com | Phone: +91-9123456789 | Amount: USD300']

# %% [markdown]
# This will display nicely in Jupyter notebook with:
# - **Bold headings** (## and ###)
# - **Code block** with syntax highlighting
# - **Bullet points** for the conditions
# - **Bold text** for emphasis on the threshold values
#
# Alternatively, if you want a more compact version:
#
# ```markdown
# # Assignment 2: Data Structures & Functions
#
# ## 1. Customer Segmentation Engine
#
# **Given Data:**
# ```python
# customers = [
#     {"id": 1, "age": 25, "income": 50000, "spend": 20000},
#     {"id": 2, "age": 45, "income": 120000, "spend": 80000},
#     {"id": 3, "age": 35, "income": 70000, "spend": 30000}
# ]

# %%
customers = [
    {"id": 1, "age": 25, "income": 50000, "spend": 20000},
    {"id": 2, "age": 45, "income": 120000, "spend": 80000},
    {"id": 3, "age": 35, "income": 70000, "spend": 30000}
]

def segment_customer(customer):
    ratio = customer["spend"] / customer["income"]
    if ratio > 0.6:
        return "High Value"
    elif 0.3 <= ratio <= 0.6:
        return "Medium Value"
    else:
        return "Low Value"

result = {cust["id"]: segment_customer(cust) for cust in customers}

print(result)
# Out:
# {1: 'Medium Value', 2: 'High Value', 3: 'Medium Value'}

# %% [markdown]
# ## 2. Text Cleaning Pipeline
#
# You are given:
#
# ```python
# texts = [
#     "Hello!!! How are you???",
#     "This is    AI     class.",
#     "Python@@@is###great"
# ]
#
# 1. Write a function clean_text(text):
# 2. Remove special characters
# 3. Remove extra spaces
# 4. Convert text to lowercase
# 5. Apply the function to all elements using loop or map
# 6. Return cleaned list

# %%
import re

texts = [
    "Hello!!! How are you???",
    "This is    AI     class.",
    "Python@@@is###great"
]

def clean_text(text):
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    text = re.sub(r'\s+', ' ', text)
    return text.strip().lower()

cleaned = [clean_text(t) for t in texts]

print(cleaned)
# Out:
# ['hello how are you', 'this is ai class', 'pythonisgreat']

# %% [markdown]
# # 🚨 Fraud Detection Rule Engine
#
# ## 📌 Problem Statement
#
# You are given a list of transactions:
#
# ```python
# transactions = [
#     {"id": 101, "amount": 5000, "location": "India"},
#     {"id": 102, "amount": 200000, "location": "Unknown"},
#     {"id": 103, "amount": 1000, "location": "India"}
# ]
#
# Task:
#
# 1. Write a function is_fraud(transaction)
# 2. If amount is greater than 100000 or location is "Unknown" mark as fraud
# 3. Otherwise mark as safe
# 4. Use lambda with filter or map
# 5. Return only fraud transactions

# %%
transactions = [
    {"id": 101, "amount": 5000, "location": "India"},
    {"id": 102, "amount": 200000, "location": "Unknown"},
    {"id": 103, "amount": 1000, "location": "India"}
]

def is_fraud(transaction):
    return transaction["amount"] > 100000 or transaction["location"] == "Unknown"

fraud_transactions = list(filter(lambda t: is_fraud(t), transactions))

print(fraud_transactions)
# Out:
# [{'id': 102, 'amount': 200000, 'location': 'Unknown'}]

# %% [markdown]
# ## 4. Feature Engineering
#
# You are given:
#
# ```python
# data = [
#     {"salary": 50000, "experience": 2},
#     {"salary": 100000, "experience": 5}
# ]
#
# Task:
#
# 1. Write a function feature_engineer(record)
# 2. Add a new key salary_per_exp
# 3. salary_per_exp is salary divided by experience
# 4. Handle division by zero using conditional logic
# 5. Return updated dataset

# %%
data = [
    {"salary": 50000, "experience": 2},
    {"salary": 100000, "experience": 5}
]

def feature_engineer(record):
    if record["experience"] != 0:
        record["salary_per_exp"] = record["salary"] / record["experience"]
    else:
        record["salary_per_exp"] = 0
    return record

updated_data = [feature_engineer(d) for d in data]

print(updated_data)
# Out:
# [{'salary': 50000, 'experience': 2, 'salary_per_exp': 25000.0}, {'salary': 100000, 'experience': 5, 'salary_per_exp': 20000.0}]

# %% [markdown]
# ## 5. Custom Reduce Function
#
# You are given:
#
# ```python
# accuracies = [0.8, 0.75, 0.9, 0.85]
#
# Task:
#
# 1. Use reduce function to calculate average accuracy
# 2. Do not use sum function
# 3. Show intermediate logic using a custom function

# %%
from functools import reduce

accuracies = [0.8, 0.75, 0.9, 0.85]

def custom_sum(x, y):
    return x + y

total = reduce(custom_sum, accuracies)

average = total / len(accuracies)

print("Average Accuracy:", average)
# Out:
# Average Accuracy: 0.8250000000000001

# %% [markdown]
# ## 6. Sequence Pattern Detection
#
# You are given:
#
# ```python
# data = [10, 20, 30, 25, 40, 50]
#
# Task:
#
# 1. Write a function detect_increasing_sequence(data)
# 2. Find the longest continuous increasing sequence
# 3. Return that sequence as a list
#
# Example output:
#
# [10, 20, 30]

# %%
data = [10, 20, 30, 25, 40, 50]

def detect_increasing_sequence(data):
    longest = []
    current = [data[0]]
    
    for i in range(1, len(data)):
        if data[i] > data[i-1]:
            current.append(data[i])
        else:
            if len(current) > len(longest):
                longest = current
            current = [data[i]]
    
    if len(current) > len(longest):
        longest = current
    
    return longest

result = detect_increasing_sequence(data)

print(result)
# Out:
# [10, 20, 30]

# %% [markdown]
# ## 7. Dictionary-Based Recommendation System
#
# You are given:
#
# ```python
# user_purchases = {
#     "user1": ["apple", "banana"],
#     "user2": ["banana", "orange"],
#     "user3": ["apple", "orange"]
# }
#
# Task:
#
# 1. Write a function recommend(user)
# 2. Recommend items based on common items between users
# 3. Do not recommend items already purchased by the user
# 4. Use sets and dictionary iteration

# %%
user_purchases = {
    "user1": ["apple", "banana"],
    "user2": ["banana", "orange"],
    "user3": ["apple", "orange"]
}

def recommend(user):
    target_items = set(user_purchases[user])
    recommendations = set()
    
    for other_user, items in user_purchases.items():
        if other_user != user:
            other_items = set(items)
            if target_items & other_items:
                recommendations.update(other_items - target_items)
    
    return list(recommendations)

print(recommend("user1"))
# Out:
# ['orange']

# %% [markdown]
# ## 8. Recursive Decision Tree Simulation
#
# **Task:**
#
# 1. Write a recursive function `decision_tree(score)`
# 2. If score is greater than 80 return `"Approved"`
# 3. If score is between 50 and 80 call the function again with score plus 10
# 4. If score is less than 50 return `"Rejected"`

# %%
def decision_tree(score):
    if score > 80:
        return "Approved"
    elif 50 <= score <= 80:
        return decision_tree(score + 10)
    else:
        return "Rejected"

score = int(input("Enter score: "))

result = decision_tree(score)

print(result)
# Out:
# Rejected
